# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
base_path = '/Users/codycombs/Documents/data/bacteria_rp/analysis/400nm_poly/dataframe/'
df = pd.read_pickle(base_path+'df_processed.pkl')

# %%
for i,row in df.iterrows():
    plt.plot(row.i,linewidth=0.5)
    plt.show()

# %%
plt.plot(df.iloc[1].t,df.iloc[1].i)
